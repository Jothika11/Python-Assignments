# %% [markdown]
# **List and its default functions**
#
# 1) *lst.append()* -  adds an item to the end of the list.
#
# 2) *lst.extend()* -  add all the elements of an iterable to the end of the list.
#
# 3) *lst.insert()* -  insert an element to the list at the specifeid index.
#
# 4) *lst.remove()* -  removes the first matching element from the list.
#
# 5) *lst.count()*  -  returns the number of items the specified element in the list.

# %%
lst=["hai",55,66,77,88]

# %%
#lst.append()
lst.append(100)

# %%
lst
# Out:
# ['hai', 55, 66, 77, 88, 100]

# %%
#lst.extend()
lst.extend("hai")

# %%
lst
# Out:
# ['hai', 55, 66, 77, 88, 100, 'h', 'a', 'i']

# %%
#lst.insert()
lst.insert(1,"Jothika")

# %%
lst
# Out:
# ['hai', 'Jothika', 55, 66, 77, 88, 100, 'h', 'a', 'i']

# %%
#lst.remove()
lst.remove(55)

# %%
lst
# Out:
# ['hai', 'Jothika', 66, 77, 88, 100, 'h', 'a', 'i']

# %%
lst.append(66)

# %%
lst
# Out:
# ['hai', 'Jothika', 66, 77, 88, 100, 'h', 'a', 'i', 66]

# %%
#lst.count()
lst.count(66)
# Out:
# 2

# %% [markdown]
# **Dictionary and its default functions**
#
# 1) *dit.pop()* - Removes a particular item in a ditionary.
#
# 2) *dit.items()* - Return a new object of the dictionary's items in (key, value) format.
#
# 3) *dit.keys()* - Returns a new object of the dictionary's key.
#
# 4) *dit.values(*) - Returns a new object of the dictionary's values.
#
# 5) *dit.clear()* - Removes all items from the dictionary.

# %%
dit={"Name":"M.Jothika","Age":"20","Gender":"Female","School":"SAMHSS",}

# %%
#dit.pop()
dit.pop("School")
# Out:
# 'SAMHSS'

# %%
dit
# Out:
# {'Age': '20', 'Gender': 'Female', 'Name': 'M.Jothika'}

# %%
#dit.items()
dit.items()
# Out:
# dict_items([('Name', 'M.Jothika'), ('Age', '20'), ('Gender', 'Female')])

# %%
#dit.keys()
dit.keys()
# Out:
# dict_keys(['Name', 'Age', 'Gender'])

# %%
#dit.values()
dit.values()
# Out:
# dict_values(['M.Jothika', '20', 'Female'])

# %%
#dit.clear()
dit.clear()

# %%
dit
# Out:
# {}

# %% [markdown]
# **Sets and its default functions**
#
# 1) *st.add()* - Adds an element to the set.
#
# 2) *st.union()* - Returns the union of sets in a new set.
#
# 3) *st.difference()* - Returns the different of two or more sets as a new set.
#
# 4) *st.clear()* - Removes all elements from the set
#
# 5) *st.copy()* - Returns a copy of the set.

# %%
st1={"Anaconda","Python",1,2,3,3,3,4,4,5}

# %%
st1
# Out:
# {1, 2, 3, 4, 5, 'Anaconda', 'Python'}

# %%
#st.add()
st1.add("Letsupgrade")

# %%
st1
# Out:
# {1, 2, 3, 4, 5, 'Anaconda', 'Letsupgrade', 'Python'}

# %%
st2={"hai","Letsupgrade","Community",1,2,3,4,5,6,7}

# %%
st2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'Community', 'Letsupgrade', 'hai'}

# %%
#st.union()
st3=st1.union(st2)

# %%
st3
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'Anaconda', 'Community', 'Letsupgrade', 'Python', 'hai'}

# %%
#st.difference()
st4=st1.difference(st2)

# %%
st4
# Out:
# {'Anaconda', 'Python'}

# %%
#st.clear()
st1.clear()

# %%
st1
# Out:
# set()

# %%
#st.copy()
st2.copy()
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'Community', 'Letsupgrade', 'hai'}

# %%
st2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'Community', 'Letsupgrade', 'hai'}

# %% [markdown]
# **Tuples and its default methods**
#
# 1) *tup.count()* - Returns the number of times a specified values occurs in a tuple
#
# 2) *tup.index()* - Searches the tuple for a specified value and returns the position of where it was found.

# %%
tup=("Hi","Hi","Hi","LetsUpgrade","Jothika")

# %%
#tup.count()
tup.count("Hi")
# Out:
# 3

# %%
#tup.index()
tup.index("Jothika")
# Out:
# 4

# %% [markdown]
# **Strings and its default methods**
#
# 1) *str.capatalize()* - Converts the first character o upper case.
#
# 2) *str.casefold()* - Converts string into lower case.
#
# 3) *str.center()*  - Returns a centered string.
#
# 4) *str.count()* - Returns the number of times a specified value occurs in a string.
#
# 5) *str.encode()* - Returns an encode version of the string.

# %%
str="hey this is jothika from letsupgrade community"

# %%
str
# Out:
# 'hey this is jothika from letsupgrade community'

# %%
#str.capatalize()
str.capitalize()
# Out:
# 'Hey this is jothika from letsupgrade community'

# %%
str1="HEY THIS IS JOTHIKA FORM LETSUPGRADE COMMUNITY"

# %%
#str.casefold()
str1.casefold()
# Out:
# 'hey this is jothika form letsupgrade community'

# %%
#str.center()
str.center(2)
# Out:
# 'hey this is jothika from letsupgrade community'

# %%
#str.count()
str.count("hey")
# Out:
# 1

# %%
#str.encode()
str.encode()
# Out:
# b'hey this is jothika from letsupgrade community'
